# %% [markdown]
# Supplemental topics
# ===================
#
# You can find the SAMS-2023 videos at this playlist: https://www.youtube.com/playlist?list=PL0sMmOaE_gs2VXTkxt1A7TYnQOg2uBE6z.
#
# The videos are sort of organized below.

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # Python scripts in Jupyter lab

# %%
YouTubeVideo('ors701V8NIk')
